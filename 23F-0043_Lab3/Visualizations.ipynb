# %% [markdown]
# ## Uninformed Search Strategies
#
# In uninformed (blind) search strategies, we don't have any additional information other than the information provided in the problem formulation (states, actions, initial state and goal state(s)).
#
# - BFS (Breadth First Search)
# - UCS (Uniform Cost Search)
# - DFS (Depth First Search)
# - DLS (Depth Limitted Search)
# - IDS (Iterative Deepening Search)

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import matplotlib.pyplot as plt
from provided.utils import show_solution
from provided.npuzzle import NPuzzleState

# %% [markdown]
# ## BFS (Breath First Search)

# %%
from Task1 import BFS

start_state = [
    2, 8, 3, 
    1, 6, 4, 
    7, 0, 5]

goal_state = [
    1, 2, 3, 
    8, 0, 4,
    7, 6, 5]

start_state, goal_state = NPuzzleState(tiles=start_state), NPuzzleState(tiles=goal_state)

solution_path, numnodes = BFS(start_state, goal_state)
print(f'{numnodes} nodes generated in this search')
show_solution(start_state, solution_path, ncols=6)
plt.show()
# Out:
# 70 nodes generated in this search

# %% [markdown]
# ## UCS (Uniform Cost Search)

# %%
from Task2 import UCS

start_state = [
    2, 8, 3, 
    1, 6, 4, 
    7, 0, 5]

goal_state = [
    1, 2, 3, 
    8, 0, 4,
    7, 6, 5]

start_state, goal_state = NPuzzleState(tiles=start_state), NPuzzleState(tiles=goal_state)

solution_path, numnodes = UCS(start_state, goal_state)
print(f'{numnodes} nodes generated in this search')
show_solution(start_state, solution_path, ncols=6)
plt.show()
# Out:
# 122 nodes generated in this search

# %% [markdown]
# ## DFS (Depth First Search)

# %%
from Task3 import DFS

start_state = [
    2, 8, 3, 
    1, 6, 4, 
    7, 0, 5]

goal_state = [
    1, 2, 3, 
    8, 0, 4,
    7, 6, 5]

start_state, goal_state = NPuzzleState(tiles=start_state), NPuzzleState(tiles=goal_state)

solution_path, numnodes = DFS(start_state, goal_state)
print(f'{numnodes} nodes generated in this search')
show_solution(start_state, solution_path, ncols=6)
plt.show()
# Out:
# 85 nodes generated in this search

# %% [markdown]
# # DLS (Depth Limited Search)

# %%
from Task4 import DLS

start_state = [
    2, 8, 3, 
    1, 6, 4, 
    7, 0, 5]

goal_state = [
    1, 2, 3, 
    8, 0, 4,
    7, 6, 5]

start_state, goal_state = NPuzzleState(tiles=start_state), NPuzzleState(tiles=goal_state)

# %%
# for depth 15
solution_path, numnodes = DLS(start_state, goal_state, 15)
print(f'{numnodes} nodes generated in this search')
show_solution(start_state, solution_path, ncols=6)
plt.show()
# Out:
# 1225 nodes generated in this search

# %%
# for depth 10
solution_path, numnodes = DLS(start_state, goal_state, 10)
print(f'{numnodes} nodes generated in this search')
show_solution(start_state, solution_path, ncols=6)
plt.show()
# Out:
# 475 nodes generated in this search

# %%
# for depth 5
solution_path, numnodes = DLS(start_state, goal_state, 5)
print(f'{numnodes} nodes generated in this search')
show_solution(start_state, solution_path, ncols=6)
plt.show()
# Out:
# 55 nodes generated in this search

# %%
# for depth 3
solution_path, numnodes = DLS(start_state, goal_state, 3)
print(f'{numnodes} nodes generated in this search')
show_solution(start_state, solution_path, ncols=6)
plt.show()
# Out:
# 26 nodes generated in this search
# No solution found!

# %% [markdown]
# ## IDS (Iterative Deepening Search)

# %%
from Task5 import IDS

start_state = [
    2, 8, 3, 
    1, 6, 4, 
    7, 0, 5]

goal_state = [
    1, 2, 3, 
    8, 0, 4,
    7, 6, 5]

start_state, goal_state = NPuzzleState(tiles=start_state), NPuzzleState(tiles=goal_state)

solution_path, numnodes, totalnode = IDS(start_state, goal_state)
print(f'{numnodes} nodes generated in this search')
print(f'{totalnode} nodes generated in total')
show_solution(start_state, solution_path, ncols=6)
# Out:
# 55 nodes generated in this search
# 145 nodes generated in total
