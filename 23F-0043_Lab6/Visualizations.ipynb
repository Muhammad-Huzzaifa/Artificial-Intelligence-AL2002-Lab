# %% [markdown]
# ## Local Search Algorithms
#
# In local search algorithms, we can estimate the goal. We have a current solution, and we can generate a new solution by applying a small change to the current solution
#
# - Hill Climbing Search
# - Simulated Annealing Search
# - Local Beam Search

# %%
import sys
import os

sys.path.append(os.path.join(os.getcwd(), '..'))

from provided.nqueens import NQueensState, NQueensStatePermutation

# %% [markdown]
# ## Hill Climbing Search

# %%
from Task1 import HillClimbingSearch

# %%
state = NQueensState.random_state(8)

search = HillClimbingSearch()
result = search.search(state)
search.plot_hist()
result
# Out:
# NQueensState(queens=[5, 2, 8, 3, 7, 4, 1, 1])

# %%
state = NQueensStatePermutation.random_state(8)

search = HillClimbingSearch()
result = search.search(state)
search.plot_hist()
result
# Out:
# NQueensStatePermutation(queens=[4, 1, 7, 3, 6, 2, 5, 8])

# %% [markdown]
# ## Simulated Anealing Search

# %%
from Task2 import SeamulatedAnealingSearch

# %%
state = NQueensState.random_state(8)

search = SeamulatedAnealingSearch()
result = search.search(state)
search.plot_hist_temp()
result
# Out:
# NQueensState(queens=[6, 5, 3, 2, 1, 3, 8, 4])

# %%
state = NQueensStatePermutation.random_state(8)

search = SeamulatedAnealingSearch()
result = search.search(state)
search.plot_hist_temp()
result
# Out:
# NQueensStatePermutation(queens=[4, 3, 7, 6, 2, 8, 5, 1])

# %% [markdown]
# ## Local Beam Search

# %%
from Task3 import LocalBeamSearch

# %%
k = 10
states = [NQueensState.random_state(8) for _ in range(k)]

search = LocalBeamSearch(10)
result = search.search(states)
search.plot_hist()
result
# Out:
# NQueensState(queens=[2, 7, 5, 8, 1, 4, 6, 3])

# %%
k = 10
states = [NQueensStatePermutation.random_state(8) for _ in range(k)]

search = LocalBeamSearch(10)
result = search.search(states)
search.plot_hist()
result
# Out:
# NQueensStatePermutation(queens=[6, 3, 1, 8, 5, 2, 4, 7])
